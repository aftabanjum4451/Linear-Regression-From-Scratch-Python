# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# import data
import pandas as pd
df=pd.read_csv('/content/gdrive/MyDrive/pytorch learning and project/liner regression from scratch/airfoil_self_noise.csv',header=None)

# %%
df.columns=['Freq','Angle','Chord_length','Free_stream','d_thickness','targets']
df.shape
# Out:
# (1503, 6)

# %%
df.head()
# Out:
#    Freq  Angle  Chord_length  Free_stream  d_thickness  targets
# 0   800    0.0        0.3048         71.3     0.002663  126.201
# 1  1000    0.0        0.3048         71.3     0.002663  125.201
# 2  1250    0.0        0.3048         71.3     0.002663  125.951
# 3  1600    0.0        0.3048         71.3     0.002663  127.591
# 4  2000    0.0        0.3048         71.3     0.002663  127.461

# %%
#check null values
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (1503, 6)

# %%
import torch 
import numpy as np

# %%
# Input array
inputs = np.array(df.drop('targets', 1), dtype='float32')
targets = np.array(df['targets'], dtype='float32')

# %%
inputs.shape,targets.shape
# Out:
# ((1503, 5), (1503,))

# %%
# Convert inputs and targets to tensors
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)
print(inputs)
print(targets)
# Out:
# tensor([[8.0000e+02, 0.0000e+00, 3.0480e-01, 7.1300e+01, 2.6634e-03],
#         [1.0000e+03, 0.0000e+00, 3.0480e-01, 7.1300e+01, 2.6634e-03],
#         [1.2500e+03, 0.0000e+00, 3.0480e-01, 7.1300e+01, 2.6634e-03],
#         ...,
#         [4.0000e+03, 1.5600e+01, 1.0160e-01, 3.9600e+01, 5.2849e-02],
#         [5.0000e+03, 1.5600e+01, 1.0160e-01, 3.9600e+01, 5.2849e-02],
#         [6.3000e+03, 1.5600e+01, 1.0160e-01, 3.9600e+01, 5.2849e-02]])
# tensor([126.2010, 125.2010, 125.9510,  ..., 106.6040, 106.2240, 104.2040])

# %%
print(targets)
# Out:
# tensor([126.2010, 125.2010, 125.9510,  ..., 106.6040, 106.2240, 104.2040])

# %%
# Weights and biases
w = torch.randn(2, 3, requires_grad=True)
b = torch.randn(2, requires_grad=True)
print(w)
print(b)
# Out:
# tensor([[ 0.3335, -1.6975,  0.4210],
#         [ 0.6724,  0.5188, -0.5035]], requires_grad=True)
# tensor([-1.0449, -0.7559], requires_grad=True)

# %%
df.columns
# Out:
# Index(['Freq', 'Angle', 'Chord_length', 'Free_stream', 'd_thickness',
#        'targets'],
#       dtype='object')

# %% [markdown]
# ## Linear regression

# %% [markdown]
# In a linear regression model, each target variable is estimated to be a weighted sum of the input variables, offset by some constant, known as a bias.
#
# Scaled sound pressure (outpt)= w11 * Freq + w12 * Angle + w13 * Chord_length + w14 * Free_stream + w15 * d_thickness + b1

# %% [markdown]
# ## Initialize the weights & biase

# %%
# Weights and biases
w = torch.randn(1, 5, requires_grad=True)
b = torch.randn(1, requires_grad=True)
print(w)
print(b)
# Out:
# tensor([[-0.1302, -0.5869,  2.3823, -0.8717,  0.2931]], requires_grad=True)
# tensor([1.3238], requires_grad=True)

# %% [markdown]
# torch.randn creates a tensor with the given shape, with elements picked randomly from a normal distribution with mean 0 and standard deviation 1

# %% [markdown]
# ### Model

# %%
# model function 
def model(x):
    return x @ w.t() + b

# %%
# Generate predictions
preds = model(inputs)
print(preds)
print(targets)
# Out:
# tensor([[-164.2502],
#         [-190.2872],
#         [-222.8334],
#         ...,
#         [-562.8321],
#         [-693.0168],
#         [-862.2568]], grad_fn=<AddBackward0>)
# tensor([126.2010, 125.2010, 125.9510,  ..., 106.6040, 106.2240, 104.2040])

# %% [markdown]
# ### Loss function

# %% [markdown]
# The model prediction and actual outputs have a huge difference so we need a loss function minmize the error.

# %%
# MSE loss
def mse(t1, t2):
    t1=t1.squeeze()
    #print('t1',t1.shape)
    #print('t2',t2.shape)
    loss_fn = torch.nn.MSELoss()
    RMSE_loss = torch.sqrt(loss_fn(t1, t2))
    return RMSE_loss

# %%
# Compute loss
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(683.0771, grad_fn=<SqrtBackward>)

# %% [markdown]
# ### Compute gradients

# %%
# Compute gradients
loss.backward()

# %%
# Gradients for weights
print(w)
print(w.grad)
# Out:
# tensor([[-0.4475,  0.0515,  0.2133, -0.9735, -0.7686]], requires_grad=True)
# tensor([[-4.2650e+03, -3.7642e+00, -9.8052e-02, -3.8202e+01, -5.9094e-03]])

# %% [markdown]
# ### Adjust weights and biases to reduce the loss

# %%
print(w)
print(w.grad)
# Out:
# tensor([[-0.4475,  0.0515,  0.2133, -0.9735, -0.7686]], requires_grad=True)
# tensor([[-4.2650e+03, -3.7642e+00, -9.8052e-02, -3.8202e+01, -5.9094e-03]])

# %% [markdown]
# We multiply the gradients with a very small number (10^-5 in this case) to ensure that we don't modify the weights by a very large amount. We want to take a small step in the downhill direction of the gradient, not a giant leap. This number is called the learning rate of the algorithm.

# %%
# learning arte --> 1e-5
with torch.no_grad():
    w -= w.grad * 1e-5
    b -= b.grad * 1e-5

# %%
# Let's verify that the loss is actually lower
loss = mse(preds, targets)

# %% [markdown]
# Need to do gradients to zero bacause PyTorch accumulates gradients, otherwise next time we invoke .backward on the loss, the new gradient values are added to the existing gradients, which may lead to unexpected results.

# %%
w.grad.zero_()
b.grad.zero_()
print(w.grad)
print(b.grad)
# Out:
# tensor([[0., 0., 0., 0., 0.]])
# tensor([0.])

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)

# %% [markdown]
# ## Train the model using gradient descent

# %%
targets
# Out:
# tensor([126.2010, 125.2010, 125.9510,  ..., 106.6040, 106.2240, 104.2040])

# %%
# Train for 100 epochs
for i in range(1000):
    preds = model(inputs)
    loss = mse(preds, targets)
    print('RMSE:',loss)
    loss.backward()
    with torch.no_grad():
        w -= w.grad * 1e-6
        b -= b.grad * 1e-6
        w.grad.zero_()
        b.grad.zero_()
# Out:
# RMSE: tensor(12804.8984, grad_fn=<SqrtBackward>)
# RMSE: tensor(12786.6338, grad_fn=<SqrtBackward>)
# RMSE: tensor(12768.3691, grad_fn=<SqrtBackward>)
# RMSE: tensor(12750.1045, grad_fn=<SqrtBackward>)
# RMSE: tensor(12731.8398, grad_fn=<SqrtBackward>)
# RMSE: tensor(12713.5742, grad_fn=<SqrtBackward>)
# RMSE: tensor(12695.3086, grad_fn=<SqrtBackward>)
# RMSE: tensor(12677.0439, grad_fn=<SqrtBackward>)
# RMSE: tensor(12658.7783, grad_fn=<SqrtBackward>)
# RMSE: tensor(12640.5137, grad_fn=<SqrtBackward>)
# RMSE: tensor(12622.2500, grad_fn=<SqrtBackward>)
# RMSE: tensor(12603.9844, grad_fn=<SqrtBackward>)
# RMSE: tensor(12585.7188, grad_fn=<SqrtBackward>)
# RMSE: tensor(12567.4541, grad_fn=<SqrtBackward>)
# RMSE: tensor(12549.1895, grad_fn=<SqrtBackward>)
# RMSE: tensor(12530.9238, grad_fn=<SqrtBackward>)
# RMSE: tensor(12512.6602, grad_fn=<SqrtBackward>)
# RMSE: tensor(12494.3945, grad_fn=<SqrtBackward>)
# RMSE: tensor(12476.1299, grad_fn=<SqrtBackward>)
# RMSE: tensor(12457.8652, grad_fn=<SqrtBackward>)
# RMSE: tensor(12439.5996, grad_fn=<SqrtBackward>)
# RMSE: tensor(12421.3359, grad_fn=<SqrtBackward>)
# RMSE: tensor(12403.0703, grad_fn=<SqrtBackward>)
# RMSE: tensor(12384.8057, grad_fn=<SqrtBackward>)
# RMSE: tensor(12366.5400, grad_fn=<SqrtBackward>)
# RMSE: tensor(12348.2754, grad_fn=<SqrtBackward>)
# RMSE: tensor(12330.0098, grad_fn=<SqrtBackward>)
# RMSE: tensor(12311.7451, grad_fn=<SqrtBackward>)
# RMSE: tensor(12293.4805, grad_fn=<SqrtBackward>)
# RMSE: tensor(12275.2148, grad_fn=<SqrtBackward>)
# RMSE: tensor(12256.9512, grad_fn=<SqrtBackward>)
# RMSE: tensor(12238.6855, grad_fn=<SqrtBackward>)
# RMSE: tensor(12220.4209, grad_fn=<SqrtBackward>)
# RMSE: tensor(12202.1553, grad_fn=<SqrtBackward>)
# RMSE: tensor(12183.8906, grad_fn=<SqrtBackward>)
# RMSE: tensor(12165.6250, grad_fn=<SqrtBackward>)
# RMSE: tensor(12147.3613, grad_fn=<SqrtBackward>)
# RMSE: tensor(12129.0967, grad_fn=<SqrtBackward>)
# RMSE: tensor(12110.8311, grad_fn=<SqrtBackward>)
# RMSE: tensor(12092.5664, grad_fn=<SqrtBackward>)
# RMSE: tensor(12074.3018, grad_fn=<SqrtBackward>)
# RMSE: tensor(12056.0361, grad_fn=<SqrtBackward>)
# RMSE: tensor(12037.7715, grad_fn=<SqrtBackward>)
# RMSE: tensor(12019.5059, grad_fn=<SqrtBackward>)
# RMSE: tensor(12001.2422, grad_fn=<SqrtBackward>)
# RMSE: tensor(11982.9766, grad_fn=<SqrtBackward>)
# RMSE: tensor(11964.7119, grad_fn=<SqrtBackward>)
# RMSE: tensor(11946.4473, grad_fn=<SqrtBackward>)
# RMSE: tensor(11928.1816, grad_fn=<SqrtBackward>)
# RMSE: tensor(11909.9170, grad_fn=<SqrtBackward>)
# RMSE: tensor(11891.6523, grad_fn=<SqrtBackward>)
# RMSE: tensor(11873.3867, grad_fn=<SqrtBackward>)
# RMSE: tensor(11855.1221, grad_fn=<SqrtBackward>)
# RMSE: tensor(11836.8574, grad_fn=<SqrtBackward>)
# RMSE: tensor(11818.5918, grad_fn=<SqrtBackward>)
# RMSE: tensor(11800.3271, grad_fn=<SqrtBackward>)
# RMSE: tensor(11782.0625, grad_fn=<SqrtBackward>)
# RMSE: tensor(11763.7979, grad_fn=<SqrtBackward>)
# RMSE: tensor(11745.5322, grad_fn=<SqrtBackward>)
# RMSE: tensor(11727.2676, grad_fn=<SqrtBackward>)
# RMSE: tensor(11709.0029, grad_fn=<SqrtBackward>)
# RMSE: tensor(11690.7383, grad_fn=<SqrtBackward>)
# RMSE: tensor(11672.4727, grad_fn=<SqrtBackward>)
# RMSE: tensor(11654.2080, grad_fn=<SqrtBackward>)
# RMSE: tensor(11635.9434, grad_fn=<SqrtBackward>)
# RMSE: tensor(11617.6768, grad_fn=<SqrtBackward>)
# RMSE: tensor(11599.4131, grad_fn=<SqrtBackward>)
# RMSE: tensor(11581.1484, grad_fn=<SqrtBackward>)
# RMSE: tensor(11562.8838, grad_fn=<SqrtBackward>)
# RMSE: tensor(11544.6191, grad_fn=<SqrtBackward>)
# RMSE: tensor(11526.3535, grad_fn=<SqrtBackward>)
# RMSE: tensor(11508.0889, grad_fn=<SqrtBackward>)
# RMSE: tensor(11489.8232, grad_fn=<SqrtBackward>)
# RMSE: tensor(11471.5586, grad_fn=<SqrtBackward>)
# RMSE: tensor(11453.2939, grad_fn=<SqrtBackward>)
# RMSE: tensor(11435.0283, grad_fn=<SqrtBackward>)
# RMSE: tensor(11416.7637, grad_fn=<SqrtBackward>)
# RMSE: tensor(11398.4990, grad_fn=<SqrtBackward>)
# RMSE: tensor(11380.2344, grad_fn=<SqrtBackward>)
# RMSE: tensor(11361.9688, grad_fn=<SqrtBackward>)
# RMSE: tensor(11343.7051, grad_fn=<SqrtBackward>)
# RMSE: tensor(11325.4395, grad_fn=<SqrtBackward>)
# RMSE: tensor(11307.1748, grad_fn=<SqrtBackward>)
# RMSE: tensor(11288.9092, grad_fn=<SqrtBackward>)
# RMSE: tensor(11270.6436, grad_fn=<SqrtBackward>)
# RMSE: tensor(11252.3789, grad_fn=<SqrtBackward>)
# RMSE: tensor(11234.1152, grad_fn=<SqrtBackward>)
# RMSE: tensor(11215.8496, grad_fn=<SqrtBackward>)
# RMSE: tensor(11197.5850, grad_fn=<SqrtBackward>)
# RMSE: tensor(11179.3203, grad_fn=<SqrtBackward>)
# RMSE: tensor(11161.0547, grad_fn=<SqrtBackward>)
# RMSE: tensor(11142.7900, grad_fn=<SqrtBackward>)
# RMSE: tensor(11124.5254, grad_fn=<SqrtBackward>)
# RMSE: tensor(11106.2598, grad_fn=<SqrtBackward>)
# RMSE: tensor(11087.9951, grad_fn=<SqrtBackward>)
# RMSE: tensor(11069.7305, grad_fn=<SqrtBackward>)
# RMSE: tensor(11051.4648, grad_fn=<SqrtBackward>)
# RMSE: tensor(11033.2012, grad_fn=<SqrtBackward>)
# RMSE: tensor(11014.9355, grad_fn=<SqrtBackward>)
# RMSE: tensor(10996.6699, grad_fn=<SqrtBackward>)
# RMSE: tensor(10978.4053, grad_fn=<SqrtBackward>)
# RMSE: tensor(10960.1416, grad_fn=<SqrtBackward>)
# RMSE: tensor(10941.8760, grad_fn=<SqrtBackward>)
# RMSE: tensor(10923.6113, grad_fn=<SqrtBackward>)
# RMSE: tensor(10905.3467, grad_fn=<SqrtBackward>)
# RMSE: tensor(10887.0811, grad_fn=<SqrtBackward>)
# RMSE: tensor(10868.8164, grad_fn=<SqrtBackward>)
# RMSE: tensor(10850.5518, grad_fn=<SqrtBackward>)
# RMSE: tensor(10832.2871, grad_fn=<SqrtBackward>)
# RMSE: tensor(10814.0215, grad_fn=<SqrtBackward>)
# RMSE: tensor(10795.7568, grad_fn=<SqrtBackward>)
# RMSE: tensor(10777.4922, grad_fn=<SqrtBackward>)
# RMSE: tensor(10759.2266, grad_fn=<SqrtBackward>)
# RMSE: tensor(10740.9619, grad_fn=<SqrtBackward>)
# RMSE: tensor(10722.6973, grad_fn=<SqrtBackward>)
# RMSE: tensor(10704.4316, grad_fn=<SqrtBackward>)
# RMSE: tensor(10686.1670, grad_fn=<SqrtBackward>)
# RMSE: tensor(10667.9014, grad_fn=<SqrtBackward>)
# RMSE: tensor(10649.6367, grad_fn=<SqrtBackward>)
# RMSE: tensor(10631.3721, grad_fn=<SqrtBackward>)
# RMSE: tensor(10613.1074, grad_fn=<SqrtBackward>)
# RMSE: tensor(10594.8428, grad_fn=<SqrtBackward>)
# RMSE: tensor(10576.5771, grad_fn=<SqrtBackward>)
# RMSE: tensor(10558.3125, grad_fn=<SqrtBackward>)
# RMSE: tensor(10540.0479, grad_fn=<SqrtBackward>)
# RMSE: tensor(10521.7832, grad_fn=<SqrtBackward>)
# RMSE: tensor(10503.5176, grad_fn=<SqrtBackward>)
# RMSE: tensor(10485.2529, grad_fn=<SqrtBackward>)
# RMSE: tensor(10466.9893, grad_fn=<SqrtBackward>)
# RMSE: tensor(10448.7256, grad_fn=<SqrtBackward>)
# RMSE: tensor(10430.4619, grad_fn=<SqrtBackward>)
# RMSE: tensor(10412.1982, grad_fn=<SqrtBackward>)
# RMSE: tensor(10393.9336, grad_fn=<SqrtBackward>)
# RMSE: tensor(10375.6699, grad_fn=<SqrtBackward>)
# RMSE: tensor(10357.4062, grad_fn=<SqrtBackward>)
# RMSE: tensor(10339.1416, grad_fn=<SqrtBackward>)
# RMSE: tensor(10320.8779, grad_fn=<SqrtBackward>)
# RMSE: tensor(10302.6143, grad_fn=<SqrtBackward>)
# RMSE: tensor(10284.3506, grad_fn=<SqrtBackward>)
# RMSE: tensor(10266.0859, grad_fn=<SqrtBackward>)
# RMSE: tensor(10247.8232, grad_fn=<SqrtBackward>)
# RMSE: tensor(10229.5596, grad_fn=<SqrtBackward>)
# RMSE: tensor(10211.2949, grad_fn=<SqrtBackward>)
# RMSE: tensor(10193.0312, grad_fn=<SqrtBackward>)
# RMSE: tensor(10174.7676, grad_fn=<SqrtBackward>)
# RMSE: tensor(10156.5029, grad_fn=<SqrtBackward>)
# RMSE: tensor(10138.2393, grad_fn=<SqrtBackward>)
# RMSE: tensor(10119.9756, grad_fn=<SqrtBackward>)
# RMSE: tensor(10101.7119, grad_fn=<SqrtBackward>)
# RMSE: tensor(10083.4482, grad_fn=<SqrtBackward>)
# RMSE: tensor(10065.1836, grad_fn=<SqrtBackward>)
# RMSE: tensor(10046.9199, grad_fn=<SqrtBackward>)
# RMSE: tensor(10028.6562, grad_fn=<SqrtBackward>)
# RMSE: tensor(10010.3926, grad_fn=<SqrtBackward>)
# RMSE: tensor(9992.1279, grad_fn=<SqrtBackward>)
# RMSE: tensor(9973.8643, grad_fn=<SqrtBackward>)
# RMSE: tensor(9955.6006, grad_fn=<SqrtBackward>)
# RMSE: tensor(9937.3369, grad_fn=<SqrtBackward>)
# RMSE: tensor(9919.0732, grad_fn=<SqrtBackward>)
# RMSE: tensor(9900.8086, grad_fn=<SqrtBackward>)
# RMSE: tensor(9882.5459, grad_fn=<SqrtBackward>)
# RMSE: tensor(9864.2812, grad_fn=<SqrtBackward>)
# RMSE: tensor(9846.0176, grad_fn=<SqrtBackward>)
# RMSE: tensor(9827.7529, grad_fn=<SqrtBackward>)
# RMSE: tensor(9809.4893, grad_fn=<SqrtBackward>)
# RMSE: tensor(9791.2256, grad_fn=<SqrtBackward>)
# RMSE: tensor(9772.9619, grad_fn=<SqrtBackward>)
# RMSE: tensor(9754.6982, grad_fn=<SqrtBackward>)
# RMSE: tensor(9736.4346, grad_fn=<SqrtBackward>)
# RMSE: tensor(9718.1709, grad_fn=<SqrtBackward>)
# RMSE: tensor(9699.9062, grad_fn=<SqrtBackward>)
# RMSE: tensor(9681.6426, grad_fn=<SqrtBackward>)
# RMSE: tensor(9663.3789, grad_fn=<SqrtBackward>)
# RMSE: tensor(9645.1152, grad_fn=<SqrtBackward>)
# RMSE: tensor(9626.8516, grad_fn=<SqrtBackward>)
# RMSE: tensor(9608.5879, grad_fn=<SqrtBackward>)
# RMSE: tensor(9590.3232, grad_fn=<SqrtBackward>)
# RMSE: tensor(9572.0596, grad_fn=<SqrtBackward>)
# RMSE: tensor(9553.7949, grad_fn=<SqrtBackward>)
# RMSE: tensor(9535.5322, grad_fn=<SqrtBackward>)
# RMSE: tensor(9517.2676, grad_fn=<SqrtBackward>)
# RMSE: tensor(9499.0039, grad_fn=<SqrtBackward>)
# RMSE: tensor(9480.7402, grad_fn=<SqrtBackward>)
# RMSE: tensor(9462.4766, grad_fn=<SqrtBackward>)
# RMSE: tensor(9444.2129, grad_fn=<SqrtBackward>)
# RMSE: tensor(9425.9492, grad_fn=<SqrtBackward>)
# RMSE: tensor(9407.6855, grad_fn=<SqrtBackward>)
# RMSE: tensor(9389.4209, grad_fn=<SqrtBackward>)
# RMSE: tensor(9371.1562, grad_fn=<SqrtBackward>)
# RMSE: tensor(9352.8926, grad_fn=<SqrtBackward>)
# RMSE: tensor(9334.6289, grad_fn=<SqrtBackward>)
# RMSE: tensor(9316.3652, grad_fn=<SqrtBackward>)
# RMSE: tensor(9298.1016, grad_fn=<SqrtBackward>)
# RMSE: tensor(9279.8379, grad_fn=<SqrtBackward>)
# RMSE: tensor(9261.5742, grad_fn=<SqrtBackward>)
# RMSE: tensor(9243.3105, grad_fn=<SqrtBackward>)
# RMSE: tensor(9225.0459, grad_fn=<SqrtBackward>)
# RMSE: tensor(9206.7832, grad_fn=<SqrtBackward>)
# RMSE: tensor(9188.5186, grad_fn=<SqrtBackward>)
# RMSE: tensor(9170.2549, grad_fn=<SqrtBackward>)
# RMSE: tensor(9151.9902, grad_fn=<SqrtBackward>)
# RMSE: tensor(9133.7266, grad_fn=<SqrtBackward>)
# RMSE: tensor(9115.4629, grad_fn=<SqrtBackward>)
# RMSE: tensor(9097.1992, grad_fn=<SqrtBackward>)
# RMSE: tensor(9078.9355, grad_fn=<SqrtBackward>)
# RMSE: tensor(9060.6719, grad_fn=<SqrtBackward>)
# RMSE: tensor(9042.4072, grad_fn=<SqrtBackward>)
# RMSE: tensor(9024.1436, grad_fn=<SqrtBackward>)
# RMSE: tensor(9005.8799, grad_fn=<SqrtBackward>)
# RMSE: tensor(8987.6162, grad_fn=<SqrtBackward>)
# RMSE: tensor(8969.3525, grad_fn=<SqrtBackward>)
# RMSE: tensor(8951.0889, grad_fn=<SqrtBackward>)
# RMSE: tensor(8932.8242, grad_fn=<SqrtBackward>)
# RMSE: tensor(8914.5605, grad_fn=<SqrtBackward>)
# RMSE: tensor(8896.2969, grad_fn=<SqrtBackward>)
# RMSE: tensor(8878.0322, grad_fn=<SqrtBackward>)
# RMSE: tensor(8859.7695, grad_fn=<SqrtBackward>)
# RMSE: tensor(8841.5049, grad_fn=<SqrtBackward>)
# RMSE: tensor(8823.2422, grad_fn=<SqrtBackward>)
# RMSE: tensor(8804.9785, grad_fn=<SqrtBackward>)
# RMSE: tensor(8786.7139, grad_fn=<SqrtBackward>)
# RMSE: tensor(8768.4512, grad_fn=<SqrtBackward>)
# RMSE: tensor(8750.1855, grad_fn=<SqrtBackward>)
# RMSE: tensor(8731.9219, grad_fn=<SqrtBackward>)
# RMSE: tensor(8713.6582, grad_fn=<SqrtBackward>)
# RMSE: tensor(8695.3945, grad_fn=<SqrtBackward>)
# RMSE: tensor(8677.1309, grad_fn=<SqrtBackward>)
# RMSE: tensor(8658.8672, grad_fn=<SqrtBackward>)
# RMSE: tensor(8640.6035, grad_fn=<SqrtBackward>)
# RMSE: tensor(8622.3389, grad_fn=<SqrtBackward>)
# RMSE: tensor(8604.0762, grad_fn=<SqrtBackward>)
# RMSE: tensor(8585.8125, grad_fn=<SqrtBackward>)
# RMSE: tensor(8567.5479, grad_fn=<SqrtBackward>)
# RMSE: tensor(8549.2832, grad_fn=<SqrtBackward>)
# RMSE: tensor(8531.0186, grad_fn=<SqrtBackward>)
# RMSE: tensor(8512.7549, grad_fn=<SqrtBackward>)
# RMSE: tensor(8494.4902, grad_fn=<SqrtBackward>)
# RMSE: tensor(8476.2266, grad_fn=<SqrtBackward>)
# RMSE: tensor(8457.9619, grad_fn=<SqrtBackward>)
# RMSE: tensor(8439.6973, grad_fn=<SqrtBackward>)
# RMSE: tensor(8421.4326, grad_fn=<SqrtBackward>)
# RMSE: tensor(8403.1680, grad_fn=<SqrtBackward>)
# RMSE: tensor(8384.9043, grad_fn=<SqrtBackward>)
# RMSE: tensor(8366.6396, grad_fn=<SqrtBackward>)
# RMSE: tensor(8348.3760, grad_fn=<SqrtBackward>)
# RMSE: tensor(8330.1113, grad_fn=<SqrtBackward>)
# RMSE: tensor(8311.8467, grad_fn=<SqrtBackward>)
# RMSE: tensor(8293.5830, grad_fn=<SqrtBackward>)
# RMSE: tensor(8275.3184, grad_fn=<SqrtBackward>)
# RMSE: tensor(8257.0537, grad_fn=<SqrtBackward>)
# RMSE: tensor(8238.7900, grad_fn=<SqrtBackward>)
# RMSE: tensor(8220.5254, grad_fn=<SqrtBackward>)
# RMSE: tensor(8202.2607, grad_fn=<SqrtBackward>)
# RMSE: tensor(8183.9966, grad_fn=<SqrtBackward>)
# RMSE: tensor(8165.7324, grad_fn=<SqrtBackward>)
# RMSE: tensor(8147.4683, grad_fn=<SqrtBackward>)
# RMSE: tensor(8129.2036, grad_fn=<SqrtBackward>)
# RMSE: tensor(8110.9395, grad_fn=<SqrtBackward>)
# RMSE: tensor(8092.6748, grad_fn=<SqrtBackward>)
# RMSE: tensor(8074.4111, grad_fn=<SqrtBackward>)
# RMSE: tensor(8056.1460, grad_fn=<SqrtBackward>)
# RMSE: tensor(8037.8823, grad_fn=<SqrtBackward>)
# RMSE: tensor(8019.6177, grad_fn=<SqrtBackward>)
# RMSE: tensor(8001.3535, grad_fn=<SqrtBackward>)
# RMSE: tensor(7983.0894, grad_fn=<SqrtBackward>)
# RMSE: tensor(7964.8247, grad_fn=<SqrtBackward>)
# RMSE: tensor(7946.5605, grad_fn=<SqrtBackward>)
# RMSE: tensor(7928.2969, grad_fn=<SqrtBackward>)
# RMSE: tensor(7910.0322, grad_fn=<SqrtBackward>)
# RMSE: tensor(7891.7671, grad_fn=<SqrtBackward>)
# RMSE: tensor(7873.5029, grad_fn=<SqrtBackward>)
# RMSE: tensor(7855.2393, grad_fn=<SqrtBackward>)
# RMSE: tensor(7836.9741, grad_fn=<SqrtBackward>)
# RMSE: tensor(7818.7104, grad_fn=<SqrtBackward>)
# RMSE: tensor(7800.4463, grad_fn=<SqrtBackward>)
# RMSE: tensor(7782.1816, grad_fn=<SqrtBackward>)
# RMSE: tensor(7763.9180, grad_fn=<SqrtBackward>)
# RMSE: tensor(7745.6533, grad_fn=<SqrtBackward>)
# RMSE: tensor(7727.3892, grad_fn=<SqrtBackward>)
# RMSE: tensor(7709.1245, grad_fn=<SqrtBackward>)
# RMSE: tensor(7690.8604, grad_fn=<SqrtBackward>)
# RMSE: tensor(7672.5957, grad_fn=<SqrtBackward>)
# RMSE: tensor(7654.3320, grad_fn=<SqrtBackward>)
# RMSE: tensor(7636.0674, grad_fn=<SqrtBackward>)
# RMSE: tensor(7617.8032, grad_fn=<SqrtBackward>)
# RMSE: tensor(7599.5386, grad_fn=<SqrtBackward>)
# RMSE: tensor(7581.2744, grad_fn=<SqrtBackward>)
# RMSE: tensor(7563.0098, grad_fn=<SqrtBackward>)
# RMSE: tensor(7544.7456, grad_fn=<SqrtBackward>)
# RMSE: tensor(7526.4814, grad_fn=<SqrtBackward>)
# RMSE: tensor(7508.2173, grad_fn=<SqrtBackward>)
# RMSE: tensor(7489.9526, grad_fn=<SqrtBackward>)
# RMSE: tensor(7471.6885, grad_fn=<SqrtBackward>)
# RMSE: tensor(7453.4238, grad_fn=<SqrtBackward>)
# RMSE: tensor(7435.1606, grad_fn=<SqrtBackward>)
# RMSE: tensor(7416.8955, grad_fn=<SqrtBackward>)
# RMSE: tensor(7398.6318, grad_fn=<SqrtBackward>)
# RMSE: tensor(7380.3667, grad_fn=<SqrtBackward>)
# RMSE: tensor(7362.1025, grad_fn=<SqrtBackward>)
# RMSE: tensor(7343.8384, grad_fn=<SqrtBackward>)
# RMSE: tensor(7325.5747, grad_fn=<SqrtBackward>)
# RMSE: tensor(7307.3101, grad_fn=<SqrtBackward>)
# RMSE: tensor(7289.0459, grad_fn=<SqrtBackward>)
# RMSE: tensor(7270.7808, grad_fn=<SqrtBackward>)
# RMSE: tensor(7252.5176, grad_fn=<SqrtBackward>)
# RMSE: tensor(7234.2524, grad_fn=<SqrtBackward>)
# RMSE: tensor(7215.9888, grad_fn=<SqrtBackward>)
# RMSE: tensor(7197.7236, grad_fn=<SqrtBackward>)
# RMSE: tensor(7179.4600, grad_fn=<SqrtBackward>)
# RMSE: tensor(7161.1953, grad_fn=<SqrtBackward>)
# RMSE: tensor(7142.9316, grad_fn=<SqrtBackward>)
# RMSE: tensor(7124.6670, grad_fn=<SqrtBackward>)
# RMSE: tensor(7106.4028, grad_fn=<SqrtBackward>)
# RMSE: tensor(7088.1382, grad_fn=<SqrtBackward>)
# RMSE: tensor(7069.8745, grad_fn=<SqrtBackward>)
# RMSE: tensor(7051.6099, grad_fn=<SqrtBackward>)
# RMSE: tensor(7033.3462, grad_fn=<SqrtBackward>)
# RMSE: tensor(7015.0811, grad_fn=<SqrtBackward>)
# RMSE: tensor(6996.8174, grad_fn=<SqrtBackward>)
# RMSE: tensor(6978.5532, grad_fn=<SqrtBackward>)
# RMSE: tensor(6960.2891, grad_fn=<SqrtBackward>)
# RMSE: tensor(6942.0244, grad_fn=<SqrtBackward>)
# RMSE: tensor(6923.7598, grad_fn=<SqrtBackward>)
# RMSE: tensor(6905.4966, grad_fn=<SqrtBackward>)
# RMSE: tensor(6887.2314, grad_fn=<SqrtBackward>)
# RMSE: tensor(6868.9678, grad_fn=<SqrtBackward>)
# RMSE: tensor(6850.7031, grad_fn=<SqrtBackward>)
# RMSE: tensor(6832.4390, grad_fn=<SqrtBackward>)
# RMSE: tensor(6814.1748, grad_fn=<SqrtBackward>)
# RMSE: tensor(6795.9106, grad_fn=<SqrtBackward>)
# RMSE: tensor(6777.6460, grad_fn=<SqrtBackward>)
# RMSE: tensor(6759.3818, grad_fn=<SqrtBackward>)
# RMSE: tensor(6741.1177, grad_fn=<SqrtBackward>)
# RMSE: tensor(6722.8535, grad_fn=<SqrtBackward>)
# RMSE: tensor(6704.5884, grad_fn=<SqrtBackward>)
# RMSE: tensor(6686.3247, grad_fn=<SqrtBackward>)
# RMSE: tensor(6668.0605, grad_fn=<SqrtBackward>)
# RMSE: tensor(6649.7969, grad_fn=<SqrtBackward>)
# RMSE: tensor(6631.5317, grad_fn=<SqrtBackward>)
# RMSE: tensor(6613.2681, grad_fn=<SqrtBackward>)
# RMSE: tensor(6595.0039, grad_fn=<SqrtBackward>)
# RMSE: tensor(6576.7393, grad_fn=<SqrtBackward>)
# RMSE: tensor(6558.4756, grad_fn=<SqrtBackward>)
# RMSE: tensor(6540.2109, grad_fn=<SqrtBackward>)
# RMSE: tensor(6521.9468, grad_fn=<SqrtBackward>)
# RMSE: tensor(6503.6821, grad_fn=<SqrtBackward>)
# RMSE: tensor(6485.4189, grad_fn=<SqrtBackward>)
# RMSE: tensor(6467.1538, grad_fn=<SqrtBackward>)
# RMSE: tensor(6448.8901, grad_fn=<SqrtBackward>)
# RMSE: tensor(6430.6260, grad_fn=<SqrtBackward>)
# RMSE: tensor(6412.3613, grad_fn=<SqrtBackward>)
# RMSE: tensor(6394.0972, grad_fn=<SqrtBackward>)
# RMSE: tensor(6375.8330, grad_fn=<SqrtBackward>)
# RMSE: tensor(6357.5688, grad_fn=<SqrtBackward>)
# RMSE: tensor(6339.3047, grad_fn=<SqrtBackward>)
# RMSE: tensor(6321.0405, grad_fn=<SqrtBackward>)
# RMSE: tensor(6302.7764, grad_fn=<SqrtBackward>)
# RMSE: tensor(6284.5122, grad_fn=<SqrtBackward>)
# RMSE: tensor(6266.2480, grad_fn=<SqrtBackward>)
# RMSE: tensor(6247.9834, grad_fn=<SqrtBackward>)
# RMSE: tensor(6229.7192, grad_fn=<SqrtBackward>)
# RMSE: tensor(6211.4551, grad_fn=<SqrtBackward>)
# RMSE: tensor(6193.1909, grad_fn=<SqrtBackward>)
# RMSE: tensor(6174.9268, grad_fn=<SqrtBackward>)
# RMSE: tensor(6156.6626, grad_fn=<SqrtBackward>)
# RMSE: tensor(6138.3984, grad_fn=<SqrtBackward>)
# RMSE: tensor(6120.1343, grad_fn=<SqrtBackward>)
# RMSE: tensor(6101.8701, grad_fn=<SqrtBackward>)
# RMSE: tensor(6083.6060, grad_fn=<SqrtBackward>)
# RMSE: tensor(6065.3413, grad_fn=<SqrtBackward>)
# RMSE: tensor(6047.0771, grad_fn=<SqrtBackward>)
# RMSE: tensor(6028.8130, grad_fn=<SqrtBackward>)
# RMSE: tensor(6010.5488, grad_fn=<SqrtBackward>)
# RMSE: tensor(5992.2847, grad_fn=<SqrtBackward>)
# RMSE: tensor(5974.0205, grad_fn=<SqrtBackward>)
# RMSE: tensor(5955.7563, grad_fn=<SqrtBackward>)
# RMSE: tensor(5937.4922, grad_fn=<SqrtBackward>)
# RMSE: tensor(5919.2285, grad_fn=<SqrtBackward>)
# RMSE: tensor(5900.9639, grad_fn=<SqrtBackward>)
# RMSE: tensor(5882.6992, grad_fn=<SqrtBackward>)
# RMSE: tensor(5864.4360, grad_fn=<SqrtBackward>)
# RMSE: tensor(5846.1719, grad_fn=<SqrtBackward>)
# RMSE: tensor(5827.9072, grad_fn=<SqrtBackward>)
# RMSE: tensor(5809.6436, grad_fn=<SqrtBackward>)
# RMSE: tensor(5791.3789, grad_fn=<SqrtBackward>)
# RMSE: tensor(5773.1152, grad_fn=<SqrtBackward>)
# RMSE: tensor(5754.8506, grad_fn=<SqrtBackward>)
# RMSE: tensor(5736.5869, grad_fn=<SqrtBackward>)
# RMSE: tensor(5718.3223, grad_fn=<SqrtBackward>)
# RMSE: tensor(5700.0586, grad_fn=<SqrtBackward>)
# RMSE: tensor(5681.7944, grad_fn=<SqrtBackward>)
# RMSE: tensor(5663.5298, grad_fn=<SqrtBackward>)
# RMSE: tensor(5645.2661, grad_fn=<SqrtBackward>)
# RMSE: tensor(5627.0024, grad_fn=<SqrtBackward>)
# RMSE: tensor(5608.7383, grad_fn=<SqrtBackward>)
# RMSE: tensor(5590.4751, grad_fn=<SqrtBackward>)
# RMSE: tensor(5572.2114, grad_fn=<SqrtBackward>)
# RMSE: tensor(5553.9478, grad_fn=<SqrtBackward>)
# RMSE: tensor(5535.6841, grad_fn=<SqrtBackward>)
# RMSE: tensor(5517.4204, grad_fn=<SqrtBackward>)
# RMSE: tensor(5499.1572, grad_fn=<SqrtBackward>)
# RMSE: tensor(5480.8936, grad_fn=<SqrtBackward>)
# RMSE: tensor(5462.6294, grad_fn=<SqrtBackward>)
# RMSE: tensor(5444.3662, grad_fn=<SqrtBackward>)
# RMSE: tensor(5426.1025, grad_fn=<SqrtBackward>)
# RMSE: tensor(5407.8394, grad_fn=<SqrtBackward>)
# RMSE: tensor(5389.5752, grad_fn=<SqrtBackward>)
# RMSE: tensor(5371.3115, grad_fn=<SqrtBackward>)
# RMSE: tensor(5353.0479, grad_fn=<SqrtBackward>)
# RMSE: tensor(5334.7847, grad_fn=<SqrtBackward>)
# RMSE: tensor(5316.5210, grad_fn=<SqrtBackward>)
# RMSE: tensor(5298.2573, grad_fn=<SqrtBackward>)
# RMSE: tensor(5279.9937, grad_fn=<SqrtBackward>)
# RMSE: tensor(5261.7300, grad_fn=<SqrtBackward>)
# RMSE: tensor(5243.4663, grad_fn=<SqrtBackward>)
# RMSE: tensor(5225.2031, grad_fn=<SqrtBackward>)
# RMSE: tensor(5206.9395, grad_fn=<SqrtBackward>)
# RMSE: tensor(5188.6758, grad_fn=<SqrtBackward>)
# RMSE: tensor(5170.4126, grad_fn=<SqrtBackward>)
# RMSE: tensor(5152.1484, grad_fn=<SqrtBackward>)
# RMSE: tensor(5133.8848, grad_fn=<SqrtBackward>)
# RMSE: tensor(5115.6216, grad_fn=<SqrtBackward>)
# RMSE: tensor(5097.3584, grad_fn=<SqrtBackward>)
# RMSE: tensor(5079.0942, grad_fn=<SqrtBackward>)
# RMSE: tensor(5060.8311, grad_fn=<SqrtBackward>)
# RMSE: tensor(5042.5674, grad_fn=<SqrtBackward>)
# RMSE: tensor(5024.3037, grad_fn=<SqrtBackward>)
# RMSE: tensor(5006.0405, grad_fn=<SqrtBackward>)
# RMSE: tensor(4987.7769, grad_fn=<SqrtBackward>)
# RMSE: tensor(4969.5132, grad_fn=<SqrtBackward>)
# RMSE: tensor(4951.2500, grad_fn=<SqrtBackward>)
# RMSE: tensor(4932.9863, grad_fn=<SqrtBackward>)
# RMSE: tensor(4914.7231, grad_fn=<SqrtBackward>)
# RMSE: tensor(4896.4595, grad_fn=<SqrtBackward>)
# RMSE: tensor(4878.1958, grad_fn=<SqrtBackward>)
# RMSE: tensor(4859.9321, grad_fn=<SqrtBackward>)
# RMSE: tensor(4841.6685, grad_fn=<SqrtBackward>)
# RMSE: tensor(4823.4053, grad_fn=<SqrtBackward>)
# RMSE: tensor(4805.1421, grad_fn=<SqrtBackward>)
# RMSE: tensor(4786.8784, grad_fn=<SqrtBackward>)
# RMSE: tensor(4768.6152, grad_fn=<SqrtBackward>)
# RMSE: tensor(4750.3511, grad_fn=<SqrtBackward>)
# RMSE: tensor(4732.0879, grad_fn=<SqrtBackward>)
# RMSE: tensor(4713.8242, grad_fn=<SqrtBackward>)
# RMSE: tensor(4695.5610, grad_fn=<SqrtBackward>)
# RMSE: tensor(4677.2974, grad_fn=<SqrtBackward>)
# RMSE: tensor(4659.0337, grad_fn=<SqrtBackward>)
# RMSE: tensor(4640.7705, grad_fn=<SqrtBackward>)
# RMSE: tensor(4622.5068, grad_fn=<SqrtBackward>)
# RMSE: tensor(4604.2437, grad_fn=<SqrtBackward>)
# RMSE: tensor(4585.9800, grad_fn=<SqrtBackward>)
# RMSE: tensor(4567.7163, grad_fn=<SqrtBackward>)
# RMSE: tensor(4549.4531, grad_fn=<SqrtBackward>)
# RMSE: tensor(4531.1899, grad_fn=<SqrtBackward>)
# RMSE: tensor(4512.9263, grad_fn=<SqrtBackward>)
# RMSE: tensor(4494.6626, grad_fn=<SqrtBackward>)
# RMSE: tensor(4476.3994, grad_fn=<SqrtBackward>)
# RMSE: tensor(4458.1362, grad_fn=<SqrtBackward>)
# RMSE: tensor(4439.8726, grad_fn=<SqrtBackward>)
# RMSE: tensor(4421.6094, grad_fn=<SqrtBackward>)
# RMSE: tensor(4403.3457, grad_fn=<SqrtBackward>)
# RMSE: tensor(4385.0825, grad_fn=<SqrtBackward>)
# RMSE: tensor(4366.8188, grad_fn=<SqrtBackward>)
# RMSE: tensor(4348.5557, grad_fn=<SqrtBackward>)
# RMSE: tensor(4330.2920, grad_fn=<SqrtBackward>)
# RMSE: tensor(4312.0288, grad_fn=<SqrtBackward>)
# RMSE: tensor(4293.7656, grad_fn=<SqrtBackward>)
# RMSE: tensor(4275.5024, grad_fn=<SqrtBackward>)
# RMSE: tensor(4257.2388, grad_fn=<SqrtBackward>)
# RMSE: tensor(4238.9756, grad_fn=<SqrtBackward>)
# RMSE: tensor(4220.7124, grad_fn=<SqrtBackward>)
# RMSE: tensor(4202.4487, grad_fn=<SqrtBackward>)
# RMSE: tensor(4184.1855, grad_fn=<SqrtBackward>)
# RMSE: tensor(4165.9224, grad_fn=<SqrtBackward>)
# RMSE: tensor(4147.6587, grad_fn=<SqrtBackward>)
# RMSE: tensor(4129.3955, grad_fn=<SqrtBackward>)
# RMSE: tensor(4111.1323, grad_fn=<SqrtBackward>)
# RMSE: tensor(4092.8687, grad_fn=<SqrtBackward>)
# RMSE: tensor(4074.6055, grad_fn=<SqrtBackward>)
# RMSE: tensor(4056.3423, grad_fn=<SqrtBackward>)
# RMSE: tensor(4038.0791, grad_fn=<SqrtBackward>)
# RMSE: tensor(4019.8157, grad_fn=<SqrtBackward>)
# RMSE: tensor(4001.5525, grad_fn=<SqrtBackward>)
# RMSE: tensor(3983.2891, grad_fn=<SqrtBackward>)
# RMSE: tensor(3965.0256, grad_fn=<SqrtBackward>)
# RMSE: tensor(3946.7625, grad_fn=<SqrtBackward>)
# RMSE: tensor(3928.4995, grad_fn=<SqrtBackward>)
# RMSE: tensor(3910.2363, grad_fn=<SqrtBackward>)
# RMSE: tensor(3891.9734, grad_fn=<SqrtBackward>)
# RMSE: tensor(3873.7104, grad_fn=<SqrtBackward>)
# RMSE: tensor(3855.4473, grad_fn=<SqrtBackward>)
# RMSE: tensor(3837.1843, grad_fn=<SqrtBackward>)
# RMSE: tensor(3818.9216, grad_fn=<SqrtBackward>)
# RMSE: tensor(3800.6587, grad_fn=<SqrtBackward>)
# RMSE: tensor(3782.3955, grad_fn=<SqrtBackward>)
# RMSE: tensor(3764.1328, grad_fn=<SqrtBackward>)
# RMSE: tensor(3745.8696, grad_fn=<SqrtBackward>)
# RMSE: tensor(3727.6067, grad_fn=<SqrtBackward>)
# RMSE: tensor(3709.3440, grad_fn=<SqrtBackward>)
# RMSE: tensor(3691.0811, grad_fn=<SqrtBackward>)
# RMSE: tensor(3672.8184, grad_fn=<SqrtBackward>)
# RMSE: tensor(3654.5554, grad_fn=<SqrtBackward>)
# RMSE: tensor(3636.2922, grad_fn=<SqrtBackward>)
# RMSE: tensor(3618.0295, grad_fn=<SqrtBackward>)
# RMSE: tensor(3599.7668, grad_fn=<SqrtBackward>)
# RMSE: tensor(3581.5042, grad_fn=<SqrtBackward>)
# RMSE: tensor(3563.2410, grad_fn=<SqrtBackward>)
# RMSE: tensor(3544.9780, grad_fn=<SqrtBackward>)
# RMSE: tensor(3526.7156, grad_fn=<SqrtBackward>)
# RMSE: tensor(3508.4526, grad_fn=<SqrtBackward>)
# RMSE: tensor(3490.1899, grad_fn=<SqrtBackward>)
# RMSE: tensor(3471.9270, grad_fn=<SqrtBackward>)
# RMSE: tensor(3453.6643, grad_fn=<SqrtBackward>)
# RMSE: tensor(3435.4016, grad_fn=<SqrtBackward>)
# RMSE: tensor(3417.1389, grad_fn=<SqrtBackward>)
# RMSE: tensor(3398.8760, grad_fn=<SqrtBackward>)
# RMSE: tensor(3380.6133, grad_fn=<SqrtBackward>)
# RMSE: tensor(3362.3508, grad_fn=<SqrtBackward>)
# RMSE: tensor(3344.0886, grad_fn=<SqrtBackward>)
# RMSE: tensor(3325.8259, grad_fn=<SqrtBackward>)
# RMSE: tensor(3307.5632, grad_fn=<SqrtBackward>)
# RMSE: tensor(3289.3010, grad_fn=<SqrtBackward>)
# RMSE: tensor(3271.0386, grad_fn=<SqrtBackward>)
# RMSE: tensor(3252.7761, grad_fn=<SqrtBackward>)
# RMSE: tensor(3234.5137, grad_fn=<SqrtBackward>)
# RMSE: tensor(3216.2515, grad_fn=<SqrtBackward>)
# RMSE: tensor(3197.9890, grad_fn=<SqrtBackward>)
# RMSE: tensor(3179.7268, grad_fn=<SqrtBackward>)
# RMSE: tensor(3161.4644, grad_fn=<SqrtBackward>)
# RMSE: tensor(3143.2021, grad_fn=<SqrtBackward>)
# RMSE: tensor(3124.9399, grad_fn=<SqrtBackward>)
# RMSE: tensor(3106.6775, grad_fn=<SqrtBackward>)
# RMSE: tensor(3088.4150, grad_fn=<SqrtBackward>)
# RMSE: tensor(3070.1528, grad_fn=<SqrtBackward>)
# RMSE: tensor(3051.8906, grad_fn=<SqrtBackward>)
# RMSE: tensor(3033.6284, grad_fn=<SqrtBackward>)
# RMSE: tensor(3015.3662, grad_fn=<SqrtBackward>)
# RMSE: tensor(2997.1040, grad_fn=<SqrtBackward>)
# RMSE: tensor(2978.8420, grad_fn=<SqrtBackward>)
# RMSE: tensor(2960.5801, grad_fn=<SqrtBackward>)
# RMSE: tensor(2942.3184, grad_fn=<SqrtBackward>)
# RMSE: tensor(2924.0564, grad_fn=<SqrtBackward>)
# RMSE: tensor(2905.7947, grad_fn=<SqrtBackward>)
# RMSE: tensor(2887.5327, grad_fn=<SqrtBackward>)
# RMSE: tensor(2869.2708, grad_fn=<SqrtBackward>)
# RMSE: tensor(2851.0088, grad_fn=<SqrtBackward>)
# RMSE: tensor(2832.7471, grad_fn=<SqrtBackward>)
# RMSE: tensor(2814.4856, grad_fn=<SqrtBackward>)
# RMSE: tensor(2796.2236, grad_fn=<SqrtBackward>)
# RMSE: tensor(2777.9619, grad_fn=<SqrtBackward>)
# RMSE: tensor(2759.7004, grad_fn=<SqrtBackward>)
# RMSE: tensor(2741.4390, grad_fn=<SqrtBackward>)
# RMSE: tensor(2723.1775, grad_fn=<SqrtBackward>)
# RMSE: tensor(2704.9160, grad_fn=<SqrtBackward>)
# RMSE: tensor(2686.6545, grad_fn=<SqrtBackward>)
# RMSE: tensor(2668.3931, grad_fn=<SqrtBackward>)
# RMSE: tensor(2650.1318, grad_fn=<SqrtBackward>)
# RMSE: tensor(2631.8704, grad_fn=<SqrtBackward>)
# RMSE: tensor(2613.6094, grad_fn=<SqrtBackward>)
# RMSE: tensor(2595.3479, grad_fn=<SqrtBackward>)
# RMSE: tensor(2577.0869, grad_fn=<SqrtBackward>)
# RMSE: tensor(2558.8254, grad_fn=<SqrtBackward>)
# RMSE: tensor(2540.5642, grad_fn=<SqrtBackward>)
# RMSE: tensor(2522.3032, grad_fn=<SqrtBackward>)
# RMSE: tensor(2504.0422, grad_fn=<SqrtBackward>)
# RMSE: tensor(2485.7815, grad_fn=<SqrtBackward>)
# RMSE: tensor(2467.5208, grad_fn=<SqrtBackward>)
# RMSE: tensor(2449.2600, grad_fn=<SqrtBackward>)
# RMSE: tensor(2430.9993, grad_fn=<SqrtBackward>)
# RMSE: tensor(2412.7383, grad_fn=<SqrtBackward>)
# RMSE: tensor(2394.4775, grad_fn=<SqrtBackward>)
# RMSE: tensor(2376.2168, grad_fn=<SqrtBackward>)
# RMSE: tensor(2357.9563, grad_fn=<SqrtBackward>)
# RMSE: tensor(2339.6960, grad_fn=<SqrtBackward>)
# RMSE: tensor(2321.4355, grad_fn=<SqrtBackward>)
# RMSE: tensor(2303.1753, grad_fn=<SqrtBackward>)
# RMSE: tensor(2284.9150, grad_fn=<SqrtBackward>)
# RMSE: tensor(2266.6550, grad_fn=<SqrtBackward>)
# RMSE: tensor(2248.3945, grad_fn=<SqrtBackward>)
# RMSE: tensor(2230.1343, grad_fn=<SqrtBackward>)
# RMSE: tensor(2211.8748, grad_fn=<SqrtBackward>)
# RMSE: tensor(2193.6147, grad_fn=<SqrtBackward>)
# RMSE: tensor(2175.3550, grad_fn=<SqrtBackward>)
# RMSE: tensor(2157.0952, grad_fn=<SqrtBackward>)
# RMSE: tensor(2138.8354, grad_fn=<SqrtBackward>)
# RMSE: tensor(2120.5759, grad_fn=<SqrtBackward>)
# RMSE: tensor(2102.3164, grad_fn=<SqrtBackward>)
# RMSE: tensor(2084.0569, grad_fn=<SqrtBackward>)
# RMSE: tensor(2065.7979, grad_fn=<SqrtBackward>)
# RMSE: tensor(2047.5386, grad_fn=<SqrtBackward>)
# RMSE: tensor(2029.2795, grad_fn=<SqrtBackward>)
# RMSE: tensor(2011.0204, grad_fn=<SqrtBackward>)
# RMSE: tensor(1992.7614, grad_fn=<SqrtBackward>)
# RMSE: tensor(1974.5028, grad_fn=<SqrtBackward>)
# RMSE: tensor(1956.2440, grad_fn=<SqrtBackward>)
# RMSE: tensor(1937.9855, grad_fn=<SqrtBackward>)
# RMSE: tensor(1919.7269, grad_fn=<SqrtBackward>)
# RMSE: tensor(1901.4688, grad_fn=<SqrtBackward>)
# RMSE: tensor(1883.2103, grad_fn=<SqrtBackward>)
# RMSE: tensor(1864.9524, grad_fn=<SqrtBackward>)
# RMSE: tensor(1846.6943, grad_fn=<SqrtBackward>)
# RMSE: tensor(1828.4365, grad_fn=<SqrtBackward>)
# RMSE: tensor(1810.1790, grad_fn=<SqrtBackward>)
# RMSE: tensor(1791.9214, grad_fn=<SqrtBackward>)
# RMSE: tensor(1773.6638, grad_fn=<SqrtBackward>)
# RMSE: tensor(1755.4067, grad_fn=<SqrtBackward>)
# RMSE: tensor(1737.1495, grad_fn=<SqrtBackward>)
# RMSE: tensor(1718.8926, grad_fn=<SqrtBackward>)
# RMSE: tensor(1700.6357, grad_fn=<SqrtBackward>)
# RMSE: tensor(1682.3790, grad_fn=<SqrtBackward>)
# RMSE: tensor(1664.1226, grad_fn=<SqrtBackward>)
# RMSE: tensor(1645.8663, grad_fn=<SqrtBackward>)
# RMSE: tensor(1627.6102, grad_fn=<SqrtBackward>)
# RMSE: tensor(1609.3542, grad_fn=<SqrtBackward>)
# RMSE: tensor(1591.0986, grad_fn=<SqrtBackward>)
# RMSE: tensor(1572.8433, grad_fn=<SqrtBackward>)
# RMSE: tensor(1554.5879, grad_fn=<SqrtBackward>)
# RMSE: tensor(1536.3328, grad_fn=<SqrtBackward>)
# RMSE: tensor(1518.0779, grad_fn=<SqrtBackward>)
# RMSE: tensor(1499.8234, grad_fn=<SqrtBackward>)
# RMSE: tensor(1481.5690, grad_fn=<SqrtBackward>)
# RMSE: tensor(1463.3149, grad_fn=<SqrtBackward>)
# RMSE: tensor(1445.0610, grad_fn=<SqrtBackward>)
# RMSE: tensor(1426.8075, grad_fn=<SqrtBackward>)
# RMSE: tensor(1408.5541, grad_fn=<SqrtBackward>)
# RMSE: tensor(1390.3011, grad_fn=<SqrtBackward>)
# RMSE: tensor(1372.0485, grad_fn=<SqrtBackward>)
# RMSE: tensor(1353.7961, grad_fn=<SqrtBackward>)
# RMSE: tensor(1335.5441, grad_fn=<SqrtBackward>)
# RMSE: tensor(1317.2924, grad_fn=<SqrtBackward>)
# RMSE: tensor(1299.0411, grad_fn=<SqrtBackward>)
# RMSE: tensor(1280.7902, grad_fn=<SqrtBackward>)
# RMSE: tensor(1262.5396, grad_fn=<SqrtBackward>)
# RMSE: tensor(1244.2896, grad_fn=<SqrtBackward>)
# RMSE: tensor(1226.0398, grad_fn=<SqrtBackward>)
# RMSE: tensor(1207.7906, grad_fn=<SqrtBackward>)
# RMSE: tensor(1189.5417, grad_fn=<SqrtBackward>)
# RMSE: tensor(1171.2936, grad_fn=<SqrtBackward>)
# RMSE: tensor(1153.0458, grad_fn=<SqrtBackward>)
# RMSE: tensor(1134.7986, grad_fn=<SqrtBackward>)
# RMSE: tensor(1116.5520, grad_fn=<SqrtBackward>)
# RMSE: tensor(1098.3059, grad_fn=<SqrtBackward>)
# RMSE: tensor(1080.0604, grad_fn=<SqrtBackward>)
# RMSE: tensor(1061.8156, grad_fn=<SqrtBackward>)
# RMSE: tensor(1043.5715, grad_fn=<SqrtBackward>)
# RMSE: tensor(1025.3280, grad_fn=<SqrtBackward>)
# RMSE: tensor(1007.0854, grad_fn=<SqrtBackward>)
# RMSE: tensor(988.8436, grad_fn=<SqrtBackward>)
# RMSE: tensor(970.6027, grad_fn=<SqrtBackward>)
# RMSE: tensor(952.3625, grad_fn=<SqrtBackward>)
# RMSE: tensor(934.1235, grad_fn=<SqrtBackward>)
# RMSE: tensor(915.8854, grad_fn=<SqrtBackward>)
# RMSE: tensor(897.6484, grad_fn=<SqrtBackward>)
# RMSE: tensor(879.4125, grad_fn=<SqrtBackward>)
# RMSE: tensor(861.1779, grad_fn=<SqrtBackward>)
# RMSE: tensor(842.9445, grad_fn=<SqrtBackward>)
# RMSE: tensor(824.7125, grad_fn=<SqrtBackward>)
# RMSE: tensor(806.4819, grad_fn=<SqrtBackward>)
# RMSE: tensor(788.2529, grad_fn=<SqrtBackward>)
# RMSE: tensor(770.0256, grad_fn=<SqrtBackward>)
# RMSE: tensor(751.8001, grad_fn=<SqrtBackward>)
# RMSE: tensor(733.5765, grad_fn=<SqrtBackward>)
# RMSE: tensor(715.3550, grad_fn=<SqrtBackward>)
# RMSE: tensor(697.1358, grad_fn=<SqrtBackward>)
# RMSE: tensor(678.9189, grad_fn=<SqrtBackward>)
# RMSE: tensor(660.7047, grad_fn=<SqrtBackward>)
# RMSE: tensor(642.4933, grad_fn=<SqrtBackward>)
# RMSE: tensor(624.2849, grad_fn=<SqrtBackward>)
# RMSE: tensor(606.0800, grad_fn=<SqrtBackward>)
# RMSE: tensor(587.8787, grad_fn=<SqrtBackward>)
# RMSE: tensor(569.6814, grad_fn=<SqrtBackward>)
# RMSE: tensor(551.4885, grad_fn=<SqrtBackward>)
# RMSE: tensor(533.3005, grad_fn=<SqrtBackward>)
# RMSE: tensor(515.1177, grad_fn=<SqrtBackward>)
# RMSE: tensor(496.9410, grad_fn=<SqrtBackward>)
# RMSE: tensor(478.7709, grad_fn=<SqrtBackward>)
# RMSE: tensor(460.6081, grad_fn=<SqrtBackward>)
# RMSE: tensor(442.4537, grad_fn=<SqrtBackward>)
# RMSE: tensor(424.3085, grad_fn=<SqrtBackward>)
# RMSE: tensor(406.1740, grad_fn=<SqrtBackward>)
# RMSE: tensor(388.0514, grad_fn=<SqrtBackward>)
# RMSE: tensor(369.9425, grad_fn=<SqrtBackward>)
# RMSE: tensor(351.8495, grad_fn=<SqrtBackward>)
# RMSE: tensor(333.7748, grad_fn=<SqrtBackward>)
# RMSE: tensor(315.7216, grad_fn=<SqrtBackward>)
# RMSE: tensor(297.6937, grad_fn=<SqrtBackward>)
# RMSE: tensor(279.6958, grad_fn=<SqrtBackward>)
# RMSE: tensor(261.7339, grad_fn=<SqrtBackward>)
# RMSE: tensor(243.8158, grad_fn=<SqrtBackward>)
# RMSE: tensor(225.9515, grad_fn=<SqrtBackward>)
# RMSE: tensor(208.1546, grad_fn=<SqrtBackward>)
# RMSE: tensor(190.4429, grad_fn=<SqrtBackward>)
# RMSE: tensor(172.8418, grad_fn=<SqrtBackward>)
# RMSE: tensor(155.3867, grad_fn=<SqrtBackward>)
# RMSE: tensor(138.1298, grad_fn=<SqrtBackward>)
# RMSE: tensor(121.1496, grad_fn=<SqrtBackward>)
# RMSE: tensor(104.5696, grad_fn=<SqrtBackward>)
# RMSE: tensor(88.5900, grad_fn=<SqrtBackward>)
# RMSE: tensor(73.5475, grad_fn=<SqrtBackward>)
# RMSE: tensor(60.0123, grad_fn=<SqrtBackward>)
# RMSE: tensor(48.8850, grad_fn=<SqrtBackward>)
# RMSE: tensor(41.2225, grad_fn=<SqrtBackward>)
# RMSE: tensor(37.3063, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.9097, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.5271, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4335, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4113, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4061, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4049, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4046, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4045, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4044, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4043, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4042, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4041, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)
# RMSE: tensor(35.4040, grad_fn=<SqrtBackward>)

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(35.4040, grad_fn=<SqrtBackward>)

# %%
# Predictions # Targets
targets,preds
# Out:
# (tensor([126.2010, 125.2010, 125.9510,  ..., 106.6040, 106.2240, 104.2040]),
#  tensor([[155.5817],
#          [155.7352],
#          [155.9272],
#          ...,
#          [ 93.9913],
#          [ 94.7590],
#          [ 95.7570]], grad_fn=<AddBackward0>))
